# %%
import numpy as np

# %%
data = np.random.randint(-100, 100, 50).cumsum()
data
# Out:
# array([  89,   31,  -46,  -14,   15,  -73,  -26,   50,   95,  178,  260,
#         290,  208,  201,  233,  190,  132,  122,   71,  164,  132,  158,
#         233,  286,  257,  205,  297,  236,  335,  244,  222,  158,  257,
#         182,  233,  141,   78,   -8,    0,   26,   53,   16,  -36,  -79,
#         -32, -104,  -65, -137,  -93,    3], dtype=int32)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(50), data, 'r')
plt.title('다이어트 현황')
plt.ylabel('체중')
plt.xlabel('날짜')
# Out:
# Text(0.5, 0, '날짜')
